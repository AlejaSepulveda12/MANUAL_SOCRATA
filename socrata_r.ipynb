# %% [markdown]
# # Socrata API con R
# Ejemplo básico de conexión y descarga de datos.

# %%
library(RSocrata)
library(dplyr)

# Descargar datos
data <- read.socrata('https://data.cityofnewyork.us/resource/erm2-nwe9.json')
head(data)
